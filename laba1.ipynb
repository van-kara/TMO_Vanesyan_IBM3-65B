# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
# Будем анализировать данные только на обучающей выборке
data = pd.read_csv('Medicaldataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Будем анализировать данные только на обучающей выборке
# ----> 2 data = pd.read_csv('Global_Cybersecurity_Threats_2015-2024.csv')
#
# ...

# %%
import os

# Узнаем где находится текущий ноутбук
notebook_path = os.getcwd()
print("📁 ТЕКУЩАЯ ДИРЕКТОРИЯ (где работает ноутбук):")
print(notebook_path)
print("\n" + "="*50)

# Показываем полный путь для копирования
print("\n📋 СКОПИРУЙТЕ ЭТОТ ПУТЬ:")
print(notebook_path)

# Проверяем какие файлы уже есть в этой директории
print("\n📄 ФАЙЛЫ В ЭТОЙ ДИРЕКТОРИИ:")
for file in os.listdir():
    print(f"   - {file}")
# Out:
# 📁 ТЕКУЩАЯ ДИРЕКТОРИЯ (где работает ноутбук):
# /Users/kara_van
#
# ...
#
# 📋 СКОПИРУЙТЕ ЭТОТ ПУТЬ:
# /Users/kara_van
#
# 📄 ФАЙЛЫ В ЭТОЙ ДИРЕКТОРИИ:
#    - import networkx as nx.py
#    - .config
#    - Music
#    - norm_form.db
#    - studs.db
#    - .condarc
#    - .docker
#    - кластер.py
#    - .DS_Store
#    - python3
#    - Figure_1.png
#    - .CFUserTextEncoding
#    - .wget-hsts
#    - .xonshrc
#    - Untitled.ipynb
#    - .zshrc
#    - .ServiceHub
#    - 3 раздел.py
#    - .templateengine
#    - nms.txt
#    - .local
#    - Projects
#    - Pictures
#    - .zprofile
#    - 123.py
#    - abc.db
#    - student
#    - .nuget
#    - .zsh_history
#    - .ipython
#    - Desktop
#    - Library
#    - django-DefectDojo
#    - .matplotlib
#    - student.db
#    - Parallels
#    - .IdentityService
#    - .android
#    - .pgadmin
#    - .ms_openjdk_config
#    - tutorial.db
#    - Public
#    - .idlerc
#    - .tcshrc
#    - .venv
#    - .anaconda
#    - .ssh
#    - Applications (Parallels)
# ...

# %%
# Будем анализировать данные только на обучающей выборке
data = pd.read_csv('Medicaldataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Будем анализировать данные только на обучающей выборке
# ----> 2 data = pd.read_csv('Medicaldataset.csv')
#
# ...

# %%
# Будем анализировать данные только на обучающей выборке
data = pd.read_csv('Medicaldataset.csv')

# %%
data.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
data.shape
# Out:
# (1319, 9)
